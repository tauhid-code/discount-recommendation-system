# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('../data/Customer online delivery dataset - Customer_data.csv')

# %%
df.head(5)
# Out:
#    Age  Gender Marital Status Occupation Educational Qualifications  \
# 0   20  Female         Single    Student              Post Graduate
# 1   24  Female         Single    Student                   Graduate
# 2   22    Male         Single    Student              Post Graduate
# 3   22  Female         Single    Student                   Graduate
# 4   22    Male         Single    Student              Post Graduate
#
#    Family size Frequently used Medium Frequently ordered Meal category   \
# 0            4     Food delivery apps                         Breakfast
# 1            3     Food delivery apps                            Snacks
# 2            3     Food delivery apps                             Lunch
# 3            6     Food delivery apps                            Snacks
# 4            4                Walk-in                             Lunch
#
#                                Perference  Restaurnat Rating  ...  \
# 0          Non Veg foods (Lunch / Dinner)                  1  ...
# 1          Non Veg foods (Lunch / Dinner)                  1  ...
# 2          Non Veg foods (Lunch / Dinner)                  3  ...
# 3  Veg foods (Breakfast / Lunch / Dinner)                  2  ...
# 4          Non Veg foods (Lunch / Dinner)                  3  ...
#
#    Order Value  Ease and convenient    Self Cooking  Health Concern  \
# 0            1              Neutral         Neutral         Neutral
# 1            3       Strongly agree  Strongly agree  Strongly agree
# 2            1       Strongly agree        Disagree         Neutral
# 3            1                Agree           Agree  Strongly agree
# 4            3                Agree           Agree  Strongly agree
#
#     Late Delivery    Poor Hygiene Bad past experience  \
# 0         Neutral         Neutral             Neutral
# 1           Agree  Strongly agree      Strongly agree
# 2         Neutral           Agree               Agree
# 3         Neutral           Agree            Disagree
# 4  Strongly agree           Agree      Strongly agree
#
#   More Offers and Discount Maximum wait time Influence of rating
# 0                  Neutral        30 minutes                 Yes
# 1           Strongly agree        30 minutes                 Yes
# 2                  Neutral        45 minutes                 Yes
# 3           Strongly agree        30 minutes                 Yes
# 4                    Agree        30 minutes                 Yes
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (499, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                499 non-null    int64
#  1   Gender                             498 non-null    object
#  2   Marital Status                     499 non-null    object
#  3   Occupation                         498 non-null    object
#  4   Educational Qualifications         499 non-null    object
#  5   Family size                        499 non-null    int64
#  6   Frequently used Medium             498 non-null    object
#  7   Frequently ordered Meal category   498 non-null    object
#  8   Perference                         498 non-null    object
#  9   Restaurnat Rating                  499 non-null    int64
#  10  Delivery Rating                    499 non-null    int64
#  11  No. of orders placed               499 non-null    int64
#  12  Delivery Time                      498 non-null    object
#  13  Order Value                        499 non-null    int64
#  14  Ease and convenient                498 non-null    object
#  15  Self Cooking                       499 non-null    object
#  16  Health Concern                     498 non-null    object
#  17  Late Delivery                      499 non-null    object
#  18  Poor Hygiene                       499 non-null    object
#  19  Bad past experience                498 non-null    object
#  20  More Offers and Discount           498 non-null    object
#  21  Maximum wait time                  497 non-null    object
#  22  Influence of rating                499 non-null    object
# dtypes: int64(6), object(17)
# memory usage: 89.8+ KB

# %%
final_cols = [
    'Age',
    'Occupation',
    'Family size',
    'Frequently used Medium',
    'Frequently ordered Meal category ',
    'Perference',
    'Restaurnat Rating',
    'Delivery Rating',
    'Order Value',
    'No. of orders placed',
    'Maximum wait time',
    'More Offers and Discount',
    'Influence of rating',
    'Ease and convenient',
    'Late Delivery',
    'Bad past experience'
]

df_model = df[final_cols]

# %%
df_model.head(5)
# Out:
#    Age Occupation  Family size Frequently used Medium  \
# 0   20    Student            4     Food delivery apps
# 1   24    Student            3     Food delivery apps
# 2   22    Student            3     Food delivery apps
# 3   22    Student            6     Food delivery apps
# 4   22    Student            4                Walk-in
#
#   Frequently ordered Meal category                               Perference  \
# 0                         Breakfast          Non Veg foods (Lunch / Dinner)
# 1                            Snacks          Non Veg foods (Lunch / Dinner)
# 2                             Lunch          Non Veg foods (Lunch / Dinner)
# 3                            Snacks  Veg foods (Breakfast / Lunch / Dinner)
# 4                             Lunch          Non Veg foods (Lunch / Dinner)
#
#    Restaurnat Rating  Delivery Rating  Order Value  No. of orders placed  \
# 0                  1                1            1                   150
# 1                  1                1            3                    32
# 2                  3                5            1                   193
# 3                  2                4            1                    60
# 4                  3                1            3                   234
#
#   Maximum wait time More Offers and Discount Influence of rating  \
# 0        30 minutes                  Neutral                 Yes
# 1        30 minutes           Strongly agree                 Yes
# 2        45 minutes                  Neutral                 Yes
# 3        30 minutes           Strongly agree                 Yes
# 4        30 minutes                    Agree                 Yes
#
#   Ease and convenient   Late Delivery Bad past experience
# 0             Neutral         Neutral             Neutral
# 1      Strongly agree           Agree      Strongly agree
# 2      Strongly agree         Neutral               Agree
# 3               Agree         Neutral            Disagree
# 4               Agree  Strongly agree      Strongly agree

# %%
df_model.isnull().sum()
# Out:
# Age                                  0
# Occupation                           1
# Family size                          0
# Frequently used Medium               1
# Frequently ordered Meal category     1
# Perference                           1
# Restaurnat Rating                    0
# Delivery Rating                      0
# Order Value                          0
# No. of orders placed                 0
# Maximum wait time                    2
# More Offers and Discount             1
# Influence of rating                  0
# Ease and convenient                  1
# Late Delivery                        0
# Bad past experience                  1
# dtype: int64

# %%
num_cols = df_model.select_dtypes(include=['int64','float64']).columns
df_model[num_cols]= df_model[num_cols].fillna(df_model[num_cols].median())

# %%
cat_cols = df_model.select_dtypes(include=['object']).columns
for col in cat_cols:
    df_model[col]=df_model[col].fillna(df_model[col].mode()[0])

# %%
df_model.isnull().sum()
# Out:
# Age                                  0
# Occupation                           0
# Family size                          0
# Frequently used Medium               0
# Frequently ordered Meal category     0
# Perference                           0
# Restaurnat Rating                    0
# Delivery Rating                      0
# Order Value                          0
# No. of orders placed                 0
# Maximum wait time                    0
# More Offers and Discount             0
# Influence of rating                  0
# Ease and convenient                  0
# Late Delivery                        0
# Bad past experience                  0
# dtype: int64

# %% [markdown]
# ## ENCODING ALL CATEGORICAL VARIABLES
# strongly disagree < disagree < neutral < agree < strongly agree

# %%
df_model = df_model.copy()

# %%
ordinal_cols = [
    'Ease and convenient',
    'Late Delivery',
    'Bad past experience',
    'More Offers and Discount'
]

binary_cols = ['Influence of rating']

for col in ordinal_cols + binary_cols:
    df_model[col] = (
        df_model[col]
        .astype(str)
        .str.strip()
        .str.lower()
    )

# %%
ordinal_map = {
    'strongly disagree': 1,
    'disagree': 2,
    'neutral': 3,
    'agree': 4,
    'strongly agree': 5
}


binary_map = {
    'yes': 1,
    'no': 0
}

# %%
# Ordinal encoding
for col in ordinal_cols:
    df_model[col] = df_model[col].map(ordinal_map)

# Binary encoding
df_model['Influence of rating'] = df_model['Influence of rating'].map(binary_map)

# %%
# Fill ordinal with median
for col in ordinal_cols:
    df_model[col] = df_model[col].fillna(df_model[col].median())

# Fill binary with mode
df_model['Influence of rating'] = df_model['Influence of rating'].fillna(
    df_model['Influence of rating'].mode()[0]
)

# %%
df_model[ordinal_cols + binary_cols].isnull().sum()
# Out:
# Ease and convenient         0
# Late Delivery               0
# Bad past experience         0
# More Offers and Discount    0
# Influence of rating         0
# dtype: int64

# %%
df_model.head(5)
# Out:
#    Age Occupation  Family size Frequently used Medium  \
# 0   20    Student            4     Food delivery apps
# 1   24    Student            3     Food delivery apps
# 2   22    Student            3     Food delivery apps
# 3   22    Student            6     Food delivery apps
# 4   22    Student            4                Walk-in
#
#   Frequently ordered Meal category                               Perference  \
# 0                         Breakfast          Non Veg foods (Lunch / Dinner)
# 1                            Snacks          Non Veg foods (Lunch / Dinner)
# 2                             Lunch          Non Veg foods (Lunch / Dinner)
# 3                            Snacks  Veg foods (Breakfast / Lunch / Dinner)
# 4                             Lunch          Non Veg foods (Lunch / Dinner)
#
#    Restaurnat Rating  Delivery Rating  Order Value  No. of orders placed  \
# 0                  1                1            1                   150
# 1                  1                1            3                    32
# 2                  3                5            1                   193
# 3                  2                4            1                    60
# 4                  3                1            3                   234
#
#   Maximum wait time  More Offers and Discount  Influence of rating  \
# 0        30 minutes                         3                  1.0
# 1        30 minutes                         5                  1.0
# 2        45 minutes                         3                  1.0
# 3        30 minutes                         5                  1.0
# 4        30 minutes                         4                  1.0
#
#    Ease and convenient  Late Delivery  Bad past experience
# 0                    3              3                    3
# 1                    5              4                    5
# 2                    5              3                    4
# 3                    4              3                    2
# 4                    4              5                    5

# %%
nominal_cols = [
    'Occupation',
    'Frequently used Medium',
    'Frequently ordered Meal category ',
    'Perference'
]

df_model = pd.get_dummies(
    df_model,
    columns=nominal_cols,
    drop_first=True
)

# %%
df_model.head(5)
# Out:
#    Age  Family size  Restaurnat Rating  Delivery Rating  Order Value  \
# 0   20            4                  1                1            1
# 1   24            3                  1                1            3
# 2   22            3                  3                5            1
# 3   22            6                  2                4            1
# 4   22            4                  3                1            3
#
#    No. of orders placed Maximum wait time  More Offers and Discount  \
# 0                   150        30 minutes                         3
# 1                    32        30 minutes                         5
# 2                   193        45 minutes                         3
# 3                    60        30 minutes                         5
# 4                   234        30 minutes                         4
#
#    Influence of rating  Ease and convenient  ...  Occupation_Student  \
# 0                  1.0                    3  ...                True
# 1                  1.0                    5  ...                True
# 2                  1.0                    5  ...                True
# 3                  1.0                    4  ...                True
# 4                  1.0                    4  ...                True
#
#    Frequently used Medium_Food delivery apps  Frequently used Medium_Walk-in  \
# 0                                       True                           False
# 1                                       True                           False
# 2                                       True                           False
# 3                                       True                           False
# 4                                      False                            True
#
#    Frequently used Medium_Web browser  \
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
#
#    Frequently ordered Meal category _Dinner  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    Frequently ordered Meal category _Lunch  \
# 0                                    False
# 1                                    False
# 2                                     True
# 3                                    False
# 4                                     True
#
#    Frequently ordered Meal category _Snacks  \
# 0                                     False
# 1                                      True
# 2                                     False
# 3                                      True
# 4                                     False
#
#    Perference_Non Veg foods (Lunch / Dinner)  Perference_Sweets  \
# 0                                       True              False
# 1                                       True              False
# 2                                       True              False
# 3                                      False              False
# 4                                       True              False
#
#    Perference_Veg foods (Breakfast / Lunch / Dinner)
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                               True
# 4                                              False
#
# [5 rows x 24 columns]

# %%
df_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 24 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Age                                                499 non-null    int64
#  1   Family size                                        499 non-null    int64
#  2   Restaurnat Rating                                  499 non-null    int64
#  3   Delivery Rating                                    499 non-null    int64
#  4   Order Value                                        499 non-null    int64
#  5   No. of orders placed                               499 non-null    int64
#  6   Maximum wait time                                  499 non-null    object
#  7   More Offers and Discount                           499 non-null    int64
#  8   Influence of rating                                499 non-null    float64
#  9   Ease and convenient                                499 non-null    int64
#  10  Late Delivery                                      499 non-null    int64
#  11  Bad past experience                                499 non-null    int64
#  12  Occupation_House wife                              499 non-null    bool
#  13  Occupation_Self Employeed                          499 non-null    bool
#  14  Occupation_Student                                 499 non-null    bool
#  15  Frequently used Medium_Food delivery apps          499 non-null    bool
#  16  Frequently used Medium_Walk-in                     499 non-null    bool
#  17  Frequently used Medium_Web browser                 499 non-null    bool
#  18  Frequently ordered Meal category _Dinner           499 non-null    bool
#  19  Frequently ordered Meal category _Lunch            499 non-null    bool
#  20  Frequently ordered Meal category _Snacks           499 non-null    bool
#  21  Perference_Non Veg foods (Lunch / Dinner)          499 non-null    bool
#  22  Perference_Sweets                                  499 non-null    bool
#  23  Perference_Veg foods (Breakfast / Lunch / Dinner)  499 non-null    bool
# dtypes: bool(12), float64(1), int64(10), object(1)
# memory usage: 52.8+ KB

# %% [markdown]
# ## Combining two columns to create target column for our model

# %%
## (column1) discount sensitive columns 
df_model['is_discount_sensitive'] = (df_model['More Offers and Discount'] >= 4).astype(int)

##(column2) frequency of orders without discounts
high_order_threshold = df_model['No. of orders placed'].quantile(0.7)

df_model['is_high_order'] = (df_model['No. of orders placed'] >= high_order_threshold).astype(int)

# %%
df_model['target_disocunt_growth']= (
(df_model['is_discount_sensitive']==1) & 
(df_model['is_high_order']==0)).astype(int)

# %%
df_model['target_disocunt_growth'].value_counts()
# Out:
# target_disocunt_growth
# 0    293
# 1    206
# Name: count, dtype: int64

# %% [markdown]
# ## Now split dependent and independent variables

# %%
target = 'target_disocunt_growth'

# %%
y = df_model[target]

X = df_model.drop(columns=[
    'target_disocunt_growth',   
    'More Offers and Discount', 
    'No. of orders placed',     
    'is_discount_sensitive',    
    'is_high_order'             
])

# %%
df_model.to_csv("../data/processed_data.csv", index=False)
